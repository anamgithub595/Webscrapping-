# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import lxml

#getting the html
url = 'https://www.cricbuzz.com/cricket-series/4061/indian-premier-league-2022/stats'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'lxml')



#getting the table
table = soup.find('table', {'class': 'table table-responsive cb-series-stats'})

headers = []

for i in table.find_all('th'):
    title = i.text.strip()
    headers.append(title)

df = pd.DataFrame(columns = headers)

for row in table.find_all('tr')[1:]:
    data = row.find_all('td')
    row_data = [td.text.strip() for td in data]
    length = len(df)
    df.loc[length] = row_data
print(df)
# Out:
#    POS            PLAYER MATCHES INNS RUNS     AVG      SR  4s  6s
# 0    1       Jos Buttler       6    6  375   75.00  156.90  32  23
# 1    2          KL Rahul       7    7  265   44.17  141.71  21  11
# 2    3    Faf du Plessis       7    7  250   35.71  132.28  23   9
# 3    4       Shivam Dube       7    7  239   39.83  161.49  18  14
# 4    5      Shreyas Iyer       7    7  236   39.33  148.43  25   6
# 5    6       Tilak Varma       7    7  234   46.80  140.12  17  11
# 6    7  Suryakumar Yadav       5    5  232   58.00  153.64  17  13
# 7    8     Hardik Pandya       5    5  228   76.00  136.53  26   6
# 8    9     Robin Uthappa       7    7  227   32.43  147.40  19  14
# 9   10  Liam Livingstone       7    7  226   32.29  182.26  18  16
# 10  11   Shimron Hetmyer       6    6  223   74.33  179.84  14  17
# 11  12      Prithvi Shaw       6    6  217   36.17  170.87  29   8
# 12  13   Quinton de Kock       7    7  215   30.71  134.38  25   4
# ...

# %%
import pandas as pd 
df = pd.read_csv('cricbuzz.csv')
df.head()
# Out:
#    POS          PLAYER  MATCHES  INNS  RUNS    AVG      SR  4s  6s
# 0    1     Jos Buttler        6     6   375  75.00  156.90  32  23
# 1    2        KL Rahul        7     7   265  44.17  141.71  21  11
# 2    3  Faf du Plessis        7     7   250  35.71  132.28  23   9
# 3    4     Shivam Dube        7     7   239  39.83  161.49  18  14
# 4    5    Shreyas Iyer        7     7   236  39.33  148.43  25   6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   POS      15 non-null     int64
#  1   PLAYER   15 non-null     object
#  2   MATCHES  15 non-null     int64
#  3   INNS     15 non-null     int64
#  4   RUNS     15 non-null     int64
#  5   AVG      15 non-null     float64
#  6   SR       15 non-null     float64
#  7   4s       15 non-null     int64
#  8   6s       15 non-null     int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 1.2+ KB

# %%
import seaborn as sns
sns.barplot(df['RUNS'], df['PLAYER'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RUNS', ylabel='PLAYER'>

# %%
sns.barplot(df['AVG'], df['PLAYER'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AVG', ylabel='PLAYER'>

# %%
sns.barplot(df['4s'], df['PLAYER'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='4s', ylabel='PLAYER'>

# %%
sns.barplot(df['6s'], df['PLAYER'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='6s', ylabel='PLAYER'>

# %%
sns.barplot(df['POS'], df['SR'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='POS', ylabel='SR'>

# %%
from matplotlib import pyplot as plt

data = pd.read_csv('cricbuzz.csv', delimiter=';')

# %%
sns.barplot(df['POS'], df['AVG'])
# Out:
# /Users/kaifrehmankhan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='POS', ylabel='AVG'>

# %%
df.plot.scatter(x='POS',
               y= 'RUNS')
# Out:
# <AxesSubplot:xlabel='POS', ylabel='RUNS'>

# %%
import matplotlib.pyplot as plt
AVG = [75,44,35,39,39,46]
POS = ['A','B','C','D','E','F']
exp = [0,0,0,0,0,0]
cl = ['red','yellow','pink','white','blue','green']
plt.pie(AVG, labels = POS, explode = exp, autopct = '%2d%%', colors = cl)
plt.show()
